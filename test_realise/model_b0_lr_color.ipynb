# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import os
from os import listdir

from numpy import zeros
from numpy import asarray
from numpy import savez_compressed

from keras import callbacks
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import Sequential
from keras.optimizers import SGD, Adam
from keras.layers import Dense, Activation, Flatten 
from keras.layers import  Dropout, Conv2D, BatchNormalization 
from keras.layers import  MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras import callbacks

# %%
repTrain  = 'train_images/'
repTest   = 'test_images/'

# %%
train = pd.read_csv('train.csv')
sep = '_'
train['image'] = train['Image_Label'].apply(lambda x: x.split(sep)[0])
train['label'] = train['Image_Label'].apply(lambda x: x.split(sep)[1])
train = train.drop(['Image_Label'], axis=1)
train = train.dropna()
train.head()
# Out:
#                                        EncodedPixels        image   label
# 0  264918 937 266318 937 267718 937 269118 937 27...  0011165.jpg    Fish
# 1  1355565 1002 1356965 1002 1358365 1002 1359765...  0011165.jpg  Flower
# 4  233813 878 235213 878 236613 878 238010 881 23...  002be4f.jpg    Fish
# 5  1339279 519 1340679 519 1342079 519 1343479 51...  002be4f.jpg  Flower
# 7  67495 350 68895 350 70295 350 71695 350 73095 ...  002be4f.jpg   Sugar

# %%
#On effectue une dichotomisation des classes de nuages
classes = ['Fish', 'Flower', 'Gravel', 'Sugar']
train_encoded = train
train_encoded= train_encoded.join(pd.get_dummies(train_encoded['label']))

#On supprime ensuite les colonnes "encoded Pixels" et "label", inutiles pour l'aggregation qui suit
train_encoded = train_encoded.drop(['EncodedPixels', 'label'], axis=1)

#Enfin on fait un sous-total pour ne conserver qu'une ligne par image
train_encoded = train_encoded.groupby(['image']).sum()

train_encoded = train_encoded.reset_index(level=0)
train_encoded.head()
# Out:
#          image  Fish  Flower  Gravel  Sugar
# 0  0011165.jpg     1       1       0      0
# 1  002be4f.jpg     1       1       0      1
# 2  0031ae9.jpg     1       1       0      1
# 3  0035239.jpg     0       1       1      0
# 4  003994e.jpg     1       0       1      1

# %%
from keras.preprocessing.image import ImageDataGenerator

batch_size = 32
image_width = 140
image_height = 210

datagen = ImageDataGenerator(rescale=1./255, 
                             horizontal_flip=True,
                             vertical_flip=True,
                             rotation_range=20,
                             fill_mode='constant',
                             width_shift_range=0.1,
                             height_shift_range=0.1,
                             zoom_range=.1,                             
                             validation_split=0.2)

train_generator = datagen.flow_from_dataframe(
    dataframe=train_encoded,
    directory=repTrain,
    x_col='image',
    y_col=classes,
    subset='training',
    class_mode='raw',
    shuffle=True,                    #On melange tout
    target_size=(image_width, image_height),          #On divise la taille par 10
    batch_size=batch_size)

validation_generator = datagen.flow_from_dataframe(
    dataframe=train_encoded,
    directory=repTrain,
    x_col='image',
    y_col=classes,
    subset='validation',
    class_mode='raw',
    shuffle=True,
    target_size=(image_width, image_height),
    batch_size=batch_size)
# Out:
# Found 4437 validated image filenames.
# Found 1109 validated image filenames.

# %%
def creation_model(affichage = False):
    
    from tensorflow.keras.applications import EfficientNetB0

    efficientNet = EfficientNetB0(include_top=False,
                                  input_shape=(image_width, image_height,3))
    for layer in efficientNet.layers:
        layer.trainable = False
    
    model = Sequential()
    model.add(efficientNet)
    model.add(GlobalAveragePooling2D())
    model.add(Dense(units = 1024, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(units = 512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(units = 4, activation ='softmax'))

    if affichage == True:
        model.summary()
        
    return model

# %%
def affiche_resultat(history, epoch, lr):
    
    train_accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.figure(figsize=(14,5))
    plt.suptitle(f"Résultats obtenus avec un learning rate de {lr}")
    
    epoques = np.arange(1, epoch+1, 1)
    # Labels des axes
    plt.subplot(121)
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')

    # Courbe de la précision sur l'échantillon d'entrainement
    plt.plot(epoques,
             train_accuracy,
             label = 'Training Accuracy',
             color = 'blue')

    # Courbe de la précision sur l'échantillon de validation
    plt.plot(epoques,
             val_accuracy,
             label = 'Validation Accuracy',
             color = 'red')

    # Affichage de la légende
    plt.legend()

    plt.subplot(122)
    plt.xlabel('Epochs')
    plt.ylabel('Loss')

    # Courbe de la précision sur l'échantillon d'entrainement
    plt.plot(epoques,
             train_loss,
             label = 'Training loss',
             color = 'blue')

    # Courbe de la précision sur l'échantillon de validation
    plt.plot(epoques,
             val_loss,
             label = 'Validation loss',
             color = 'red')

    # Affichage de la légende
    plt.legend()
    
    # Affichage de la figure
    plt.show()

# %%
e_stopping = callbacks.EarlyStopping(monitor = 'val_loss',
                                     patience = 3,
                                     mode = 'min',
                                     restore_best_weights = True)

# %%
EPOCHS = 10
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=validation_generator.n//validation_generator.batch_size

# %%
model = creation_model(True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnetb0 (Functional)  (None, 5, 7, 1280)        4049571
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1311744
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 5,888,167
# Trainable params: 1,838,596
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %%
lr = 1e-3
model.compile(optimizer=Adam(lr), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch=STEP_SIZE_TRAIN,
    epochs=EPOCHS,
    validation_data=validation_generator,
    validation_steps=STEP_SIZE_VALID,
    callbacks=[e_stopping])
# Out:
# /home/joca/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/10
# 138/138 [==============================] - 189s 1s/step - loss: 0.6924 - accuracy: 0.1196 - val_loss: 0.6871 - val_accuracy: 0.1654
# Epoch 2/10
# 138/138 [==============================] - 182s 1s/step - loss: 0.6795 - accuracy: 0.0888 - val_loss: 0.6735 - val_accuracy: 0.0790
# Epoch 3/10
# 138/138 [==============================] - 182s 1s/step - loss: 0.6764 - accuracy: 0.0765 - val_loss: 0.6751 - val_accuracy: 0.0781
# Epoch 4/10
# 138/138 [==============================] - 182s 1s/step - loss: 0.6758 - accuracy: 0.0761 - val_loss: 0.6740 - val_accuracy: 0.0772
# Epoch 5/10
# 138/138 [==============================] - 182s 1s/step - loss: 0.6778 - accuracy: 0.0773 - val_loss: 0.6727 - val_accuracy: 0.0781
# Epoch 6/10
# 138/138 [==============================] - 182s 1s/step - loss: 0.6733 - accuracy: 0.0852 - val_loss: 0.6721 - val_accuracy: 0.0772
# Epoch 7/10
# 138/138 [==============================] - 182s 1s/step - loss: 0.6779 - accuracy: 0.0706 - val_loss: 0.6727 - val_accuracy: 0.0772
# Epoch 8/10
# 138/138 [==============================] - 182s 1s/step - loss: 0.6754 - accuracy: 0.0838 - val_loss: 0.6727 - val_accuracy: 0.0790
# Epoch 9/10
# 138/138 [==============================] - 182s 1s/step - loss: 0.6724 - accuracy: 0.0858 - val_loss: 0.6728 - val_accuracy: 0.0781

# %%
epoch_real = len(history.history['loss'])
affiche_resultat(history, epoch_real, lr)

# %%
model = creation_model()

# %%
lr = 1e-4
model.compile(optimizer=Adam(lr), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch=STEP_SIZE_TRAIN,
    epochs=EPOCHS,
    validation_data=validation_generator,
    validation_steps=STEP_SIZE_VALID,
    callbacks=[e_stopping])
# Out:
# /home/joca/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/10
# 138/138 [==============================] - 186s 1s/step - loss: 0.6823 - accuracy: 0.0898 - val_loss: 0.6765 - val_accuracy: 0.0781
# Epoch 2/10
# 138/138 [==============================] - 182s 1s/step - loss: 0.6803 - accuracy: 0.0738 - val_loss: 0.6723 - val_accuracy: 0.0763
# Epoch 3/10
# 138/138 [==============================] - 181s 1s/step - loss: 0.6773 - accuracy: 0.0772 - val_loss: 0.6735 - val_accuracy: 0.0781
# Epoch 4/10
# 138/138 [==============================] - 181s 1s/step - loss: 0.6775 - accuracy: 0.0764 - val_loss: 0.6718 - val_accuracy: 0.0781
# Epoch 5/10
# 138/138 [==============================] - 181s 1s/step - loss: 0.6766 - accuracy: 0.0799 - val_loss: 0.6731 - val_accuracy: 0.0772
# Epoch 6/10
# 138/138 [==============================] - 181s 1s/step - loss: 0.6761 - accuracy: 0.0793 - val_loss: 0.6728 - val_accuracy: 0.0790
# Epoch 7/10
# 138/138 [==============================] - 181s 1s/step - loss: 0.6748 - accuracy: 0.0808 - val_loss: 0.6729 - val_accuracy: 0.0781

# %%
epoch_real = len(history.history['loss'])
affiche_resultat(history, epoch_real, lr)

# %%
model = creation_model()

# %%
lr = 1e-5
model.compile(optimizer=Adam(lr), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch=STEP_SIZE_TRAIN,
    epochs=EPOCHS,
    validation_data=validation_generator,
    validation_steps=STEP_SIZE_VALID,
    callbacks=[e_stopping])
# Out:
# /home/joca/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/10
# 138/138 [==============================] - 186s 1s/step - loss: 0.6842 - accuracy: 0.1351 - val_loss: 0.6739 - val_accuracy: 0.0772
# Epoch 2/10
# 138/138 [==============================] - 182s 1s/step - loss: 0.6787 - accuracy: 0.0863 - val_loss: 0.6730 - val_accuracy: 0.0744
# Epoch 3/10
# 138/138 [==============================] - 181s 1s/step - loss: 0.6793 - accuracy: 0.0801 - val_loss: 0.6729 - val_accuracy: 0.0772
# Epoch 4/10
# 138/138 [==============================] - 181s 1s/step - loss: 0.6764 - accuracy: 0.0773 - val_loss: 0.6723 - val_accuracy: 0.0772
# Epoch 5/10
# 138/138 [==============================] - 182s 1s/step - loss: 0.6790 - accuracy: 0.0800 - val_loss: 0.6741 - val_accuracy: 0.0754
# Epoch 6/10
# 138/138 [==============================] - 181s 1s/step - loss: 0.6789 - accuracy: 0.0727 - val_loss: 0.6735 - val_accuracy: 0.0772
# Epoch 7/10
# 138/138 [==============================] - 181s 1s/step - loss: 0.6770 - accuracy: 0.0794 - val_loss: 0.6724 - val_accuracy: 0.0781

# %%
epoch_real = len(history.history['loss'])
affiche_resultat(history, epoch_real, lr)

# %%
model = creation_model()

# %%
lr = 1e-6
model.compile(optimizer=Adam(lr), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch=STEP_SIZE_TRAIN,
    epochs=EPOCHS,
    validation_data=validation_generator,
    validation_steps=STEP_SIZE_VALID,
    callbacks=[e_stopping])
# Out:
# /home/joca/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/10
# 138/138 [==============================] - 186s 1s/step - loss: 0.6844 - accuracy: 0.1944 - val_loss: 0.6764 - val_accuracy: 0.0790
# Epoch 2/10
# 138/138 [==============================] - 182s 1s/step - loss: 0.6801 - accuracy: 0.1006 - val_loss: 0.6734 - val_accuracy: 0.0772
# Epoch 3/10
# 138/138 [==============================] - 182s 1s/step - loss: 0.6757 - accuracy: 0.0832 - val_loss: 0.6729 - val_accuracy: 0.0772
# Epoch 4/10
# 138/138 [==============================] - 181s 1s/step - loss: 0.6794 - accuracy: 0.0781 - val_loss: 0.6720 - val_accuracy: 0.0781
# Epoch 5/10
# 138/138 [==============================] - 181s 1s/step - loss: 0.6782 - accuracy: 0.0869 - val_loss: 0.6717 - val_accuracy: 0.0790
# Epoch 6/10
# 138/138 [==============================] - 181s 1s/step - loss: 0.6769 - accuracy: 0.0733 - val_loss: 0.6724 - val_accuracy: 0.0763
# Epoch 7/10
# 138/138 [==============================] - 182s 1s/step - loss: 0.6797 - accuracy: 0.0729 - val_loss: 0.6716 - val_accuracy: 0.0781
# Epoch 8/10
# 138/138 [==============================] - 181s 1s/step - loss: 0.6757 - accuracy: 0.0728 - val_loss: 0.6724 - val_accuracy: 0.0781
# Epoch 9/10
# 138/138 [==============================] - 181s 1s/step - loss: 0.6767 - accuracy: 0.0752 - val_loss: 0.6718 - val_accuracy: 0.0781
# Epoch 10/10
# 138/138 [==============================] - 181s 1s/step - loss: 0.6786 - accuracy: 0.0822 - val_loss: 0.6718 - val_accuracy: 0.0772

# %%
epoch_real = len(history.history['loss'])
affiche_resultat(history, epoch_real, lr)

# %%
model = creation_model()

# %%
lr = 1e-7
model.compile(optimizer=Adam(lr), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch=STEP_SIZE_TRAIN,
    epochs=EPOCHS,
    validation_data=validation_generator,
    validation_steps=STEP_SIZE_VALID,
    callbacks=[e_stopping])
# Out:
# /home/joca/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/10
# 138/138 [==============================] - 189s 1s/step - loss: 0.7010 - accuracy: 0.2163 - val_loss: 0.6959 - val_accuracy: 0.1636
# Epoch 2/10
# 138/138 [==============================] - 184s 1s/step - loss: 0.7006 - accuracy: 0.2077 - val_loss: 0.6938 - val_accuracy: 0.1645
# Epoch 3/10
# 138/138 [==============================] - 183s 1s/step - loss: 0.6952 - accuracy: 0.2055 - val_loss: 0.6918 - val_accuracy: 0.1636
# Epoch 4/10
# 138/138 [==============================] - 183s 1s/step - loss: 0.6940 - accuracy: 0.1931 - val_loss: 0.6902 - val_accuracy: 0.1618
# Epoch 5/10
# 138/138 [==============================] - 183s 1s/step - loss: 0.6946 - accuracy: 0.1779 - val_loss: 0.6886 - val_accuracy: 0.1645
# Epoch 6/10
# 138/138 [==============================] - 187s 1s/step - loss: 0.6940 - accuracy: 0.1564 - val_loss: 0.6870 - val_accuracy: 0.1636
# Epoch 7/10
# 138/138 [==============================] - 187s 1s/step - loss: 0.6917 - accuracy: 0.1507 - val_loss: 0.6861 - val_accuracy: 0.1654
# Epoch 8/10
# 138/138 [==============================] - 184s 1s/step - loss: 0.6903 - accuracy: 0.1471 - val_loss: 0.6846 - val_accuracy: 0.0781
# Epoch 9/10
# 138/138 [==============================] - 183s 1s/step - loss: 0.6885 - accuracy: 0.1540 - val_loss: 0.6835 - val_accuracy: 0.0781
# Epoch 10/10
# 138/138 [==============================] - 184s 1s/step - loss: 0.6878 - accuracy: 0.1388 - val_loss: 0.6828 - val_accuracy: 0.0772

# %%
epoch_real = len(history.history['loss'])
affiche_resultat(history, epoch_real, lr)

# %%
model = creation_model()

# %%
lr = 1e-8
model.compile(optimizer=Adam(lr), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch=STEP_SIZE_TRAIN,
    epochs=EPOCHS,
    validation_data=validation_generator,
    validation_steps=STEP_SIZE_VALID,
    callbacks=[e_stopping])
# Out:
# /home/joca/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/10
# 138/138 [==============================] - 187s 1s/step - loss: 0.6965 - accuracy: 0.2139 - val_loss: 0.6928 - val_accuracy: 0.0781
# Epoch 2/10
# 138/138 [==============================] - 182s 1s/step - loss: 0.6965 - accuracy: 0.2148 - val_loss: 0.6928 - val_accuracy: 0.0763
# Epoch 3/10
# 138/138 [==============================] - 182s 1s/step - loss: 0.6961 - accuracy: 0.2028 - val_loss: 0.6925 - val_accuracy: 0.0790
# Epoch 4/10
# 138/138 [==============================] - 182s 1s/step - loss: 0.6966 - accuracy: 0.2080 - val_loss: 0.6923 - val_accuracy: 0.0772
# Epoch 5/10
# 138/138 [==============================] - 182s 1s/step - loss: 0.6950 - accuracy: 0.2185 - val_loss: 0.6919 - val_accuracy: 0.0781
# Epoch 6/10
# 138/138 [==============================] - 181s 1s/step - loss: 0.6949 - accuracy: 0.2090 - val_loss: 0.6919 - val_accuracy: 0.0772
# Epoch 7/10
# 138/138 [==============================] - 182s 1s/step - loss: 0.6952 - accuracy: 0.2128 - val_loss: 0.6915 - val_accuracy: 0.0772
# Epoch 8/10
# 138/138 [==============================] - 182s 1s/step - loss: 0.6946 - accuracy: 0.2070 - val_loss: 0.6915 - val_accuracy: 0.0754
# Epoch 9/10
# 138/138 [==============================] - 182s 1s/step - loss: 0.6951 - accuracy: 0.2102 - val_loss: 0.6913 - val_accuracy: 0.0763
# Epoch 10/10
# 138/138 [==============================] - 181s 1s/step - loss: 0.6939 - accuracy: 0.1993 - val_loss: 0.6912 - val_accuracy: 0.0744

# %%
epoch_real = len(history.history['loss'])
affiche_resultat(history, epoch_real, lr)

# %%
model = creation_model()

# %%
lr = 1
model.compile(optimizer=Adam(lr), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch=STEP_SIZE_TRAIN,
    epochs=EPOCHS,
    validation_data=validation_generator,
    validation_steps=STEP_SIZE_VALID,
    callbacks=[e_stopping])
# Out:
# /home/joca/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/10
# 138/138 [==============================] - 195s 1s/step - loss: 79843.3891 - accuracy: 0.2040 - val_loss: 0.6796 - val_accuracy: 0.0754
# Epoch 2/10
# 138/138 [==============================] - 192s 1s/step - loss: 0.6869 - accuracy: 0.0917 - val_loss: 0.6729 - val_accuracy: 0.0790
# Epoch 3/10
# 138/138 [==============================] - 194s 1s/step - loss: 0.6834 - accuracy: 0.1063 - val_loss: 0.6730 - val_accuracy: 0.0790
# Epoch 4/10
# 138/138 [==============================] - 193s 1s/step - loss: 0.6838 - accuracy: 0.1027 - val_loss: 0.6767 - val_accuracy: 0.0772
# Epoch 5/10
# 138/138 [==============================] - 188s 1s/step - loss: 0.6849 - accuracy: 0.1391 - val_loss: 0.6859 - val_accuracy: 0.0781

# %%
epoch_real = len(history.history['loss'])
affiche_resultat(history, epoch_real, lr)
